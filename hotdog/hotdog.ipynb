# %%
# %pylab inline
from PIL import Image
import numpy as np
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
pic = Image.open('data/hotdog-nothotdog/hotdog-nothotdog/train/hotdog/6.jpg')
np_pic = np.asarray(pic)
# should all be shape: (299, 299, 3)

# %%
imshow(pic)
